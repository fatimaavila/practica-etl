# %%
# !pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-1.5.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 7.0 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas) (2022.7.1)
# Collecting numpy>=1.21.0
#   Downloading numpy-1.24.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 5.9 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: python-dateutil>=2.8.1 in /opt/conda/lib/python3.10/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Installing collected packages: numpy, pandas
# Successfully installed numpy-1.24.2 pandas-1.5.3

# %%
import pandas as pd
import json

# %%
data = json.load(open('mpd.slice.1000-1999.json'))

# %%
playlists=data['playlists']

# %%
df = pd.DataFrame.from_dict(playlists)
df.head(5)
# Out:
#             name collaborative   pid  modified_at  num_tracks  num_albums  \
# 0         disney         false  1000   1457827200         189          16
# 1  Indie Electro         false  1001   1417824000         165          18
# 2    jack & jack         false  1002   1465430400          17          14
# 3          vibes         false  1003   1498435200         225         195
# 4          Indie         false  1004   1498608000         165         118
#
#    num_followers                                             tracks  \
# 0              1  [{'pos': 0, 'artist_name': 'Original Broadway ...
# 1              2  [{'pos': 0, 'artist_name': 'The Octopus Projec...
# 2              1  [{'pos': 0, 'artist_name': 'Jack & Jack', 'tra...
# 3              2  [{'pos': 0, 'artist_name': 'LANY', 'track_uri'...
# 4              1  [{'pos': 0, 'artist_name': 'Youth Lagoon', 'tr...
#
#    num_edits  duration_ms  num_artists description
# 0          4     31428282           65         NaN
# 1          2     38241566            8         NaN
# 2          3      3549358            3         NaN
# 3         91     51242585          157         NaN
# 4         74     42601098           92         NaN

# %%
columnas=df['tracks'][1][0].keys()
#para obtener los datos de artista, album, 
#track se tiene que extraer del array que está dentro de las tracks de cada una,
#para luego pbtener cada uno.
columnas
# Out:
# dict_keys(['pos', 'artist_name', 'track_uri', 'artist_uri', 'track_name', 'album_uri', 'duration_ms', 'album_name'])

# %%
dffull = pd.DataFrame(columns=columnas)
dffull
# Out:
# Empty DataFrame
# Columns: [pos, artist_name, track_uri, artist_uri, track_name, album_uri, duration_ms, album_name]
# Index: []

# %%
#se trabajrea con 5 playlist por ahora
df=df.head(5)
df
# Out:
#             name collaborative   pid  modified_at  num_tracks  num_albums  \
# 0         disney         false  1000   1457827200         189          16
# 1  Indie Electro         false  1001   1417824000         165          18
# 2    jack & jack         false  1002   1465430400          17          14
# 3          vibes         false  1003   1498435200         225         195
# 4          Indie         false  1004   1498608000         165         118
#
#    num_followers                                             tracks  \
# 0              1  [{'pos': 0, 'artist_name': 'Original Broadway ...
# 1              2  [{'pos': 0, 'artist_name': 'The Octopus Projec...
# 2              1  [{'pos': 0, 'artist_name': 'Jack & Jack', 'tra...
# 3              2  [{'pos': 0, 'artist_name': 'LANY', 'track_uri'...
# 4              1  [{'pos': 0, 'artist_name': 'Youth Lagoon', 'tr...
#
#    num_edits  duration_ms  num_artists description
# 0          4     31428282           65         NaN
# 1          2     38241566            8         NaN
# 2          3      3549358            3         NaN
# 3         91     51242585          157         NaN
# 4         74     42601098           92         NaN

# %%
##borrando 
dftfull = pd.DataFrame(columns=df['tracks'][0][0].keys())

for index, row in df.iterrows():
    print(row['name'], row['pid'],row['num_tracks'])
    for row2 in row['tracks']:
      dftemp = pd.DataFrame(row2,index=[0])
      dffull = dffull.append(dftemp)

# %%
dffull # se tienen todas las canciones juntas
# Out:
#     pos                                  artist_name  \
# 0     0  Original Broadway Cast - The Little Mermaid
# 0     1  Original Broadway Cast - The Little Mermaid
# 0     2  Original Broadway Cast - The Little Mermaid
# 0     3  Original Broadway Cast - The Little Mermaid
# 0     4  Original Broadway Cast - The Little Mermaid
# ..  ...                                          ...
# 0   160                               Weekend Affair
# 0   161                               Weekend Affair
# 0   162                                 Jack Garratt
# 0   163                               The Beach Boys
# 0   164                                Timber Timbre
#
#                                track_uri  \
# 0   spotify:track:5IbCV9Icebx8rR6wAp5hhP
# 0   spotify:track:6rKVAvjHcxAzZ1BHtwh5yC
# 0   spotify:track:6Jlkb1Wh08RYHstWScsTvg
# 0   spotify:track:0XhC8bfStML9ygBmfOt1JJ
# 0   spotify:track:0ABxAcsRWlqckkyONsfP67
# ..                                   ...
# 0   spotify:track:3wOeFpaSQUi1wDeiecDUod
# 0   spotify:track:3WLS3HQcz3t3d5GLPDZkcZ
# 0   spotify:track:6vRp1EGkh1SE7uGNhbqVjT
# 0   spotify:track:58TvuKjnOZK7mZp680GnqH
# 0   spotify:track:3kpRgTtMnArQ5Gay0JxElf
#
#                                artist_uri  \
# 0   spotify:artist:3TymzPhJTMyupk7P5xkahM
# 0   spotify:artist:3TymzPhJTMyupk7P5xkahM
# 0   spotify:artist:3TymzPhJTMyupk7P5xkahM
# 0   spotify:artist:3TymzPhJTMyupk7P5xkahM
# 0   spotify:artist:3TymzPhJTMyupk7P5xkahM
# ..                                    ...
# 0   spotify:artist:0dZXa7OgcOzv3tNUagbKb7
# 0   spotify:artist:0dZXa7OgcOzv3tNUagbKb7
# 0   spotify:artist:1Zp054Jc86WVKCxKEqZGOA
# 0   spotify:artist:3oDbviiivRWhXwIE8hxkVV
# 0   spotify:artist:7HeVXdOdMhLslVputGTZFQ
#
#                                            track_name  \
# 0             Fathoms Below - Broadway Cast Recording
# 0       Daughters Of Triton - Broadway Cast Recording
# 0           The World Above - Broadway Cast Recording
# 0               Human Stuff - Broadway Cast Recording
# 0   I Want the Good Times Back - Broadway Cast Rec...
# ..                                                ...
# 0                                        I Walk Alone
# 0                                           Try Again
# 0                                   Surprise Yourself
# 0                               God Only Knows - Mono
# 0                                          Hot Dreams
#
#                                album_uri duration_ms  \
# 0   spotify:album:3ULJeOMgroG27dpn27MDfS      154506
# 0   spotify:album:3ULJeOMgroG27dpn27MDfS       79066
# 0   spotify:album:3ULJeOMgroG27dpn27MDfS       94600
# 0   spotify:album:3ULJeOMgroG27dpn27MDfS      151480
# 0   spotify:album:3ULJeOMgroG27dpn27MDfS      297920
# ..                                   ...         ...
# 0   spotify:album:6FvbZMdqvXSGIwaFXPthuE      237280
# 0   spotify:album:6FvbZMdqvXSGIwaFXPthuE      211000
# 0   spotify:album:4neDtPlGoWdcLZsedOGN5E      260866
# 0   spotify:album:42oBdomfxF0DbKKMEqrnQW      173560
# 0   spotify:album:2U1BUKvsYIkUik7xEhAP0C      293213
#
#                                            album_name
# 0   The Little Mermaid: Original Broadway Cast Rec...
# 0   The Little Mermaid: Original Broadway Cast Rec...
# 0   The Little Mermaid: Original Broadway Cast Rec...
# 0   The Little Mermaid: Original Broadway Cast Rec...
# 0   The Little Mermaid: Original Broadway Cast Rec...
# ..                                                ...
# 0                                Welcome to Your Fate
# 0                                Welcome to Your Fate
# 0                                               Phase
# 0                                          Pet Sounds
# 0                                          Hot Dreams
#
# [761 rows x 8 columns]
